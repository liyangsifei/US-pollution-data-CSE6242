# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('pollution_us_2000_2016.csv', sep=',')

# %%
df.drop(columns=['State Code', 'County Code', 'Site Num', 'Address', 'NO2 Units', 'O3 Units', 'SO2 Units', 'CO Units'], inplace=True)

# %%
#df.loc[::4, ['CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour']] = np.nan
#df.fillna(method='bfill', inplace=True)

# %%
df_export = df.loc[df['Unnamed: 0'] % 4 == 1]

# %%
df_export.tail()
# Out:
#          Unnamed: 0    State   County           City  Date Local  NO2 Mean  \
# 1746642       24585  Wyoming  Laramie  Not in a city  2016-03-27  4.277273
# 1746646       24589  Wyoming  Laramie  Not in a city  2016-03-28  8.317391
# 1746650       24593  Wyoming  Laramie  Not in a city  2016-03-29  2.564706
# 1746654       24597  Wyoming  Laramie  Not in a city  2016-03-30  1.083333
# 1746658       24601  Wyoming  Laramie  Not in a city  2016-03-31  0.939130
#
#          NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI   O3 Mean  ...  \
# 1746642               23.5                23       22  0.041958  ...
# 1746646               22.6                 6       21  0.041292  ...
# 1746650                3.6                 6        3  0.028000  ...
# 1746654                1.6                 9        1  0.043917  ...
# 1746658                1.3                 5        1  0.045263  ...
#
#          O3 1st Max Hour  O3 AQI  SO2 Mean  SO2 1st Max Value  \
# ...

# %%
df_export = df_export.reset_index(drop=True)
df_export.drop(columns=['Unnamed: 0'])
# Out:
#           State    County           City  Date Local   NO2 Mean  \
# 0       Arizona  Maricopa        Phoenix  2000-01-01  19.041667
# 1       Arizona  Maricopa        Phoenix  2000-01-02  22.958333
# 2       Arizona  Maricopa        Phoenix  2000-01-03  38.125000
# 3       Arizona  Maricopa        Phoenix  2000-01-04  40.260870
# 4       Arizona  Maricopa        Phoenix  2000-01-05  48.450000
# ...         ...       ...            ...         ...        ...
# 436663  Wyoming   Laramie  Not in a city  2016-03-27   4.277273
# 436664  Wyoming   Laramie  Not in a city  2016-03-28   8.317391
# 436665  Wyoming   Laramie  Not in a city  2016-03-29   2.564706
# 436666  Wyoming   Laramie  Not in a city  2016-03-30   1.083333
# 436667  Wyoming   Laramie  Not in a city  2016-03-31   0.939130
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI   O3 Mean  \
# 0                    49.0                19       46  0.022500
# 1                    36.0                19       34  0.013375
# ...

# %%
df_export.to_csv('pollution_us_2000_2016-cleaned.csv')
